# %%
import pandas as pd
import glob
import os

# %%
df = pd.read_csv("dataset")
df
# Out:
#                  artist    date                     genre  pixelsx  pixelsy  \
# 0             Hiroshige    1838  bird-and-flower painting   6483.0   9276.0
# 1             Hiroshige    1844  bird-and-flower painting   5492.0   8283.0
# 2      Utagawa Kunisada     NaN                 landscape   9293.0   4688.0
# 3             Hiroshige    1838  bird-and-flower painting   4256.0   9127.0
# 4             Hiroshige     NaN  bird-and-flower painting   4154.0   9051.0
# ...                 ...     ...                       ...      ...      ...
# 7191       August Macke    1913                still life    764.0   1074.0
# 7192         Emil Nolde    1912         symbolic painting    987.0    831.0
# 7193         Iosif Iser  1935.0                  portrait   1000.0    820.0
# 7194  Amedeo Modigliani    1919                  portrait    747.0   1097.0
# 7195  Amedeo Modigliani    1919                  portrait    729.0   1124.0
#
#       size_bytes   source          style  \
# ...

# %%
pop_art =df[df['style'] == 'Pop Art']
pop_art
# Out:
#                 artist    date             genre  pixelsx  pixelsy  \
# 96        Keith Haring    1990            poster   3384.0   2700.0
# 98    Marjorie Strider  1995.0          abstract   3533.0   2528.0
# 129   Marjorie Strider  1963.0        figurative   4160.0   1902.0
# 142   Marjorie Strider  1963.0          portrait   2418.0   3006.0
# 145   Richard Hamilton  1970.0  sketch and study   2233.0   3200.0
# ...                ...     ...               ...      ...      ...
# 5187  Roy Lichtenstein  1978.0          portrait    351.0    432.0
# 5189   Burhan Dogancay    1984        figurative    315.0    480.0
# 5191  Roy Lichtenstein  1961.0    genre painting    548.0    275.0
# 5193  Roy Lichtenstein  1964.0        still life    546.0    275.0
# 5194       Andy Warhol    1954   animal painting    335.0    448.0
#
#       size_bytes   source    style                             title  \
# 96     1024225.0  wikiart  Pop Art                      Best Buddies
# ...

# %%
text_pop_art = []
for x in pop_art['new_filename']:
    text_pop_art.append(x)
text_pop_art
# Out:
# ['9442.jpg',
#  '91399.jpg',
#  '40394.jpg',
#  '29989.jpg',
#  '96087.jpg',
#  '35040.jpg',
#  '61103.jpg',
#  '71844.jpg',
#  '24096.jpg',
#  '43115.jpg',
#  '89764.jpg',
#  '84041.jpg',
#  '103198.jpg',
#  '95802.jpg',
#  '26433.jpg',
#  '73839.jpg',
#  '52071.jpg',
#  '15239.jpg',
#  '44263.jpg',
#  '53931.jpg',
#  '49600.jpg',
#  '6115.jpg',
#  '55879.jpg',
#  '53959.jpg',
#  '52184.jpg',
#  '37196.jpg',
#  '90580.jpg',
#  '35248.jpg',
#  '41237.jpg',
#  '73663.jpg',
#  '40606.jpg',
#  '100781.jpg',
#  '88612.jpg',
#  '27936.jpg',
#  '99803.jpg',
#  '79642.jpg',
#  '6782.jpg',
#  '87596.jpg',
#  '96714.jpg',
#  '32963.jpg',
#  '54461.jpg',
#  '63282.jpg',
#  '44613.jpg',
#  '6923.jpg',
#  '51680.jpg',
#  '86075.jpg',
#  '19957.jpg',
#  '30652.jpg',
#  '37599.jpg',
#  '67760.jpg',
#  '41510.jpg',
#  '27333.jpg',
#  '99281.jpg',
#  '63060.jpg',
#  '96425.jpg',
#  '50672.jpg',
#  '75388.jpg',
#  '69227.jpg',
#  '90975.jpg',
#  '5264.jpg',
#  '145.jpg',
#  '35834.jpg',
# ...

# %%
for x in glob.glob('Inputs/imagenes_extraidas/train/*.jpg'):  
    name =x.split("/")[-1]
    if name in text_pop_art:
        os.system("mv {} ./Inputs/imagenes_extraidas/pop_art_128/{}".format(x, name))

# %%
ruta_pop_art = []
for x in text_pop_art:
    ruta_pop_art.append('Inputs/imagenes_extraidas/pop_art_128/'(*x))
ruta_pop_art
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-b36854f27d19> in <module>
#       1 ruta_pop_art = []
#       2 for x in text_pop_art:
# ----> 3     ruta_pop_art.append('Inputs/imagenes_extraidas/pop_art_128/'(*x))
#       4 ruta_pop_art
#
# TypeError: 'str' object is not callable
