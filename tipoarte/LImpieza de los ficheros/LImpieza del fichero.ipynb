# %%
import pandas as pd
import pandas as pd
# %matplotlib inline
import cv2
import matplotlib.pyplot as plt
from PIL import Image
import pytesseract
import os
import glob

# %%
df =pd.read_csv('Inputs/all_data_info.csv')

# %%
df
# Out:
#                          artist    date               genre  pixelsx  pixelsy  \
# 0                Barnett Newman  1955.0            abstract  15530.0   6911.0
# 1                Barnett Newman  1950.0            abstract  14559.0   6866.0
# 2                   kiri nichol  2013.0                 NaN   9003.0   9004.0
# 3                   kiri nichol  2013.0                 NaN   9003.0   9004.0
# 4                   kiri nichol  2013.0                 NaN   9003.0   9004.0
# ...                         ...     ...                 ...      ...      ...
# 103245          Jackson Pollock  1948.0            abstract    682.0    220.0
# 103246         Bernardo Strozzi     NaN  religious painting    329.0    456.0
# 103247               Josef Sima     NaN           landscape    293.0    512.0
# 103248           Brett Whiteley  1982.0              marina    293.0    512.0
# 103249  Amadeo de Souza-Cardoso    1913           landscape    293.0    512.0
#
# ...

# %%
a =df['style'].value_counts()
dic =dict(a)
dic
# Out:
# {'Impressionism': 10643,
#  'Realism': 10523,
#  'Romanticism': 9285,
#  'Expressionism': 7013,
#  'Post-Impressionism': 5778,
#  'Art Nouveau (Modern)': 4899,
#  'Baroque': 4400,
#  'Surrealism': 4167,
#  'Symbolism': 3476,
#  'Rococo': 2733,
#  'Northern Renaissance': 2379,
#  'Naïve Art (Primitivism)': 2295,
#  'Abstract Expressionism': 2074,
#  'Neoclassicism': 2038,
#  'Cubism': 1747,
#  'Ukiyo-e': 1426,
#  'Early Renaissance': 1351,
#  'Mannerism (Late Renaissance)': 1342,
#  'High Renaissance': 1314,
#  'Art Informel': 1267,
#  'Magic Realism': 1002,
#  'Abstract Art': 979,
#  'Academicism': 972,
#  'Color Field Painting': 910,
#  'Pop Art': 791,
#  'Fauvism': 731,
#  'Lyrical Abstraction': 670,
#  'Art Deco': 644,
#  'Concretism': 581,
#  'Neo-Romanticism': 566,
#  'Ink and wash painting': 545,
#  'Op Art': 528,
#  'Pointillism': 501,
#  'Minimalism': 460,
#  'Tachisme': 436,
#  'Naturalism': 435,
#  'Neo-Expressionism': 420,
#  'Orientalism': 392,
#  'Luminism': 385,
# ...

# %%
for key,value in dic.items():
    if value > 500:
        print(key,value)
# Out:
# Impressionism 10643
# Realism 10523
# Romanticism 9285
# Expressionism 7013
# Post-Impressionism 5778
# Art Nouveau (Modern) 4899
# Baroque 4400
# Surrealism 4167
# Symbolism 3476
# Rococo 2733
# Northern Renaissance 2379
# Naïve Art (Primitivism) 2295
# Abstract Expressionism 2074
# Neoclassicism 2038
# Cubism 1747
# Ukiyo-e 1426
# Early Renaissance 1351
# Mannerism (Late Renaissance) 1342
# High Renaissance 1314
# Art Informel 1267
# Magic Realism 1002
# Abstract Art 979
# Academicism 972
# Color Field Painting 910
# Pop Art 791
# Fauvism 731
# Lyrical Abstraction 670
# Art Deco 644
# Concretism 581
# Neo-Romanticism 566
# Ink and wash painting 545
# Op Art 528
# Pointillism 501

# %%
df =df[df['style'].isin(['Expressionism','Ukiyo-e','Cubism','Pop Art','Pointillism','Fauvism'])]
df
# Out:
#                          artist    date                     genre  pixelsx  \
# 7                     Hiroshige    1838  bird-and-flower painting   6483.0
# 10                    Hiroshige    1844  bird-and-flower painting   5492.0
# 13             Utagawa Kunisada     NaN                 landscape   9293.0
# 16                    Hiroshige    1838  bird-and-flower painting   4256.0
# 17                    Hiroshige     NaN  bird-and-flower painting   4154.0
# ...                         ...     ...                       ...      ...
# 103212    Thalia Flora-Karavia   1942.0                  portrait    338.0
# 103225            Alfredo Volpi     NaN        religious painting    334.0
# 103236         Roy Lichtenstein  1964.0                still life    546.0
# 103243              Andy Warhol    1954           animal painting    335.0
# 103249  Amadeo de Souza-Cardoso    1913                 landscape    293.0
#
#         pixelsy  size_bytes   source          style  \
# ...

# %%
all_expressionism =df[df['style'] == 'Expressionism']

# %%
# aqui me saco solo los expressionistas y lo limito a 1300 valores porque tenían muchos mas valores
#y si no me iba a quedar desbalanceado
expressionism =all_expressionism[:2000]
expressionism
# Out:
#                       artist    date              genre  pixelsx  pixelsy  \
# 90              August Macke  c.1910     genre painting   3846.0   5592.0
# 120    Ernst Ludwig Kirchner    1910             poster   3666.0   5376.0
# 146    Ernst Ludwig Kirchner    1913          landscape   4908.0   3684.0
# 165    Ernst Ludwig Kirchner    1919    animal painting   4464.0   3918.0
# 168    Ernst Ludwig Kirchner  c.1916     genre painting   3348.0   5214.0
# ...                      ...     ...                ...      ...      ...
# 39156           August Macke    1913         still life    764.0   1074.0
# 39175             Emil Nolde    1912  symbolic painting    987.0    831.0
# 39181             Iosif Iser  1935.0           portrait   1000.0    820.0
# 39219      Amedeo Modigliani    1919           portrait    747.0   1097.0
# 39222      Amedeo Modigliani    1919           portrait    729.0   1124.0
#
#        size_bytes   source          style  \
# ...

# %%
expressionismo =expressionism.to_csv('./expressionism',index=False)

# %%
# aqui me saco los otros estilos que son interesantes para realizar mi estudio
without_expresionism =df[df['style'].isin(['Ukiyo-e','Cubism','Pop Art','Pointillism','Fauvism'])]

# %%
# concateno los dos datasets que tengo separados en uno solo
data_set =pd.concat([without_expresionism,expressionism])
data_set
# Out:
#                   artist    date                     genre  pixelsx  pixelsy  \
# 7              Hiroshige    1838  bird-and-flower painting   6483.0   9276.0
# 10             Hiroshige    1844  bird-and-flower painting   5492.0   8283.0
# 13      Utagawa Kunisada     NaN                 landscape   9293.0   4688.0
# 16             Hiroshige    1838  bird-and-flower painting   4256.0   9127.0
# 17             Hiroshige     NaN  bird-and-flower painting   4154.0   9051.0
# ...                  ...     ...                       ...      ...      ...
# 39156       August Macke    1913                still life    764.0   1074.0
# 39175         Emil Nolde    1912         symbolic painting    987.0    831.0
# 39181         Iosif Iser  1935.0                  portrait   1000.0    820.0
# 39219  Amedeo Modigliani    1919                  portrait    747.0   1097.0
# 39222  Amedeo Modigliani    1919                  portrait    729.0   1124.0
#
#        size_bytes   source          style  \
# ...

# %%
# compruebo los estilos y mas o menos estan balanceados aunque haya muchos valores de mas en uno y otro
data_set['style'].value_counts()
# Out:
# Expressionism    2000
# Cubism           1747
# Ukiyo-e          1426
# Pop Art           791
# Fauvism           731
# Pointillism       501
# Name: style, dtype: int64

# %%
data_set.isnull().sum()
# Out:
# artist             0
# date            1922
# genre            102
# pixelsx            0
# pixelsy            0
# size_bytes         0
# source             0
# style              0
# title              0
# artist_group       0
# in_train           0
# new_filename       0
# dtype: int64

# %%
# me saco el dataset limpio en un csv para no perderlo mas
dataset =data_set.to_csv('./dataset',index=False)

# %%
# A partir de aqui me voy a centrar en un estilo e intento sacar sus imagenes de la carpeta que tengo
#36 Gigas de datos una maravilla pero es imposible trabajar con ellos todos juntos
cubismo =data_set[data_set['style'] == 'Cubism' ]

# %%
cubismo
# Out:
#                            artist    date              genre  pixelsx  \
# 36               Lyonel Feininger  1936.0          cityscape   4630.0
# 40               Lyonel Feininger  1924.0          cityscape   4550.0
# 43               Lyonel Feininger  1925.0          cityscape   4550.0
# 46               Lyonel Feininger  1926.0          cityscape   4472.0
# 169                     Juan Gris    1921         still life   5137.0
# ...                           ...     ...                ...      ...
# 102909                    Man Ray  1908.0   sketch and study    365.0
# 102995         Ion Alin Gheorghiu  1972.0         figurative    363.0
# 103128  Marevna (Marie Vorobieff)     NaN         still life    315.0
# 103184               Le Corbusier  1944.0  literary painting    314.0
# 103249    Amadeo de Souza-Cardoso    1913          landscape    293.0
#
#         pixelsy  size_bytes     source   style                title  \
# ...

# %%
# me saco el nomnbre de los ficheros que me interesan para buscarlos en una carpeta
text_cubismo = []
for x in cubismo['new_filename']:
    text_cubismo.append(x)

# %%
len(text_cubismo)
# Out:
# 1747

# %%
# Esta función me sirve para extraer las imagenes de cubismo que quiero en mi carpeta nueva que se llama cubismo

for x in glob.glob('Inputs/imagenes_extraidas/train/*.jpg'):  
    name =x.split("/")[-1]
    if name in text_cubismo:
        os.system("mv {} ./Inputs/imagenes_extraidas/cubism/{}".format(x, name))

# %%
dict_styles = {style: list_files}
for k,v in dict_styles.items():
    # ejecutar funcion con esos parametros

# %%
with open("cubismo_ruta.txt", "w") as output:
    output.write(str(ruta_cubismo))

# %%
def loadImageColor(imagePath):
    im = cv2.imread(imagePath)
    

    return im

# %%
loadImageColor('../Inputs/imagenes_extraidas/train/*.jpg')

# %%
dicc = {}
for x in ruta_cubismo:
    dicc[x.split('/')[-1]]= loadImageColor(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-0467ddac76b5> in <module>
#       1 dicc = {}
# ----> 2 for x in ruta_cubismo:
#       3     dicc[x.split('/')[-1]]= loadImageColor(x)
#       4
#
# NameError: name 'ruta_cubismo' is not defined

# %%
type(dicc)
# Out:
# dict

# %%
print(dicc['63416.jpg'].size)
print(dicc['63416.jpg'].shape)
# Out:
# 80808000
# (5920, 4550, 3)

# %%
cubis
# Out:
# Empty DataFrame
# Columns: [key, value]
# Index: []
