# %%
import pandas as pd
import glob
import os

# %%
df = pd.read_csv("dataset")
df
# Out:
#                      artist    date                     genre  pixelsx  \
# 0                 Hiroshige    1838  bird-and-flower painting   6483.0
# 1                 Hiroshige    1844  bird-and-flower painting   5492.0
# 2          Utagawa Kunisada     NaN                 landscape   9293.0
# 3                 Hiroshige    1838  bird-and-flower painting   4256.0
# 4                 Hiroshige     NaN  bird-and-flower painting   4154.0
# ...                     ...     ...                       ...      ...
# 6491              Lynd Ward  1929.0        nude painting (nu)    889.0
# 6492  Ernst Ludwig Kirchner     NaN        nude painting (nu)   1216.0
# 6493   Alexej von Jawlensky    1910                 landscape   1280.0
# 6494  Ernst Ludwig Kirchner     NaN                  portrait    816.0
# 6495        Martiros Saryan    1948                 landscape   1291.0
#
#       pixelsy  size_bytes     source          style  \
# 0      9276.0  12762418.0    wikiart        Ukiyo-e
# ...

# %%
ukiyo =df[df['style'] == 'Ukiyo-e']
ukiyo
# Out:
#                 artist    date                     genre  pixelsx  pixelsy  \
# 0            Hiroshige    1838  bird-and-flower painting   6483.0   9276.0
# 1            Hiroshige    1844  bird-and-flower painting   5492.0   8283.0
# 2     Utagawa Kunisada     NaN                 landscape   9293.0   4688.0
# 3            Hiroshige    1838  bird-and-flower painting   4256.0   9127.0
# 4            Hiroshige     NaN  bird-and-flower painting   4154.0   9051.0
# ...                ...     ...                       ...      ...      ...
# 5154     Paul Jacoulet  1952.0            genre painting    346.0    450.0
# 5158  Utagawa Kunisada    1864                 yakusha-e    326.0    476.0
# 5162     Paul Jacoulet  1947.0            genre painting    344.0    450.0
# 5167     Paul Jacoulet  1959.0            genre painting    343.0    450.0
# 5169     Paul Jacoulet  1959.0            genre painting    342.0    450.0
#
#       size_bytes   source    style  \
# ...

# %%
text_ukiyo = []
for x in ukiyo['new_filename']:
    text_ukiyo.append(x)
text_ukiyo
# Out:
# ['49823.jpg',
#  '53180.jpg',
#  '48138.jpg',
#  '77203.jpg',
#  '23508.jpg',
#  '27254.jpg',
#  '47145.jpg',
#  '71024.jpg',
#  '99733.jpg',
#  '73690.jpg',
#  '93715.jpg',
#  '47170.jpg',
#  '100979.jpg',
#  '216.jpg',
#  '32829.jpg',
#  '102176.jpg',
#  '82905.jpg',
#  '80633.jpg',
#  '90839.jpg',
#  '8959.jpg',
#  '71886.jpg',
#  '59682.jpg',
#  '20408.jpg',
#  '88250.jpg',
#  '65771.jpg',
#  '98553.jpg',
#  '87823.jpg',
#  '42726.jpg',
#  '67649.jpg',
#  '100455.jpg',
#  '37568.jpg',
#  '36862.jpg',
#  '8517.jpg',
#  '32539.jpg',
#  '76100.jpg',
#  '62115.jpg',
#  '19944.jpg',
#  '71417.jpg',
#  '34897.jpg',
#  '59679.jpg',
#  '19346.jpg',
#  '92045.jpg',
#  '9944.jpg',
#  '91676.jpg',
#  '6362.jpg',
#  '7288.jpg',
#  '15960.jpg',
#  '92736.jpg',
#  '50093.jpg',
#  '73066.jpg',
#  '58664.jpg',
#  '79031.jpg',
#  '68329.jpg',
#  '13211.jpg',
#  '26637.jpg',
#  '54323.jpg',
#  '4735.jpg',
#  '58764.jpg',
#  '98698.jpg',
#  '4364.jpg',
#  '82053.jpg',
#  '101278.jpg',
# ...

# %%
for x in glob.glob('Inputs/imagenes_extraidas/train/*.jpg'):  
    name =x.split("/")[-1]
    if name in text_ukiyo:
        os.system("mv {} ./Inputs/imagenes_extraidas/ukiyo_128/{}".format(x, name))
